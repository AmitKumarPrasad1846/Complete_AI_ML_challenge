# %% [markdown]
# # 🐼 Pandas: Python Data Library
#
# ## What is Pandas?
# Pandas is a powerful Python library specifically designed for **data manipulation** and **data analysis**.
# * **Stands for:** Panel Data System.
# * **Creator:** Wes McKinney (2008).
#
# ## Why was Pandas Created?
# While other libraries handle pure mathematics, Pandas was built to solve **real-world data problems**. It provides tools to easily handle messy data, including:
# * Missing values
# * Duplicates
# * Complex column names and indexing
#
# ## Core Capabilities (The Data Pipeline)
# Pandas helps you navigate the entire data lifecycle:
# 1. **Load:** Import data from various sources (CSV, Excel, SQL, etc.).
# 2. **Clean:** Handle missing data and fix formatting issues.
# 3. **Manipulate:** Filter, sort, and merge datasets.
# 4. **Transform & Explore:** Reshape data to find patterns and insights.
# 5. **Analyze:** Prepare and process data for Machine Learning (ML) models.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 🏗️ How Pandas Works: Core Data Structures
#
# Pandas relies on two primary data structures to organize and manipulate data:
#
# ## 1. Series
# * **Definition:** A **one-dimensional** labeled array/data.
# * **Concept:** Think of it as a single column or a simple list of data where each item is assigned an index (label).
#
# ## 2. DataFrame
# * **Definition:** A **two-dimensional** labeled array/data.
# * **Concept:** Think of it as a table with rows and columns (similar to an Excel spreadsheet or an SQL table). A DataFrame is essentially a collection of Series side-by-side.

# %% [markdown]
# # 📊 Pandas Series in Detail
#
# ## What is a Series?
# * **Structure:** A **one-dimensional** labeled array.
# * **Visualization:** Think of it as a simple, single column of data that comes with an attached index (row labels).
# * **Flexibility:** It can store mixed data types within the same structure, including:
#   * Numbers (integers, floats)
#   * Strings (text)
#   * Booleans (True/False)
#
# ## The Core Concept
# At its most fundamental level, a Series is made up of two components:
# > **Series = Data + Index**

# %%
#creating series
s=pd.Series([10,20,30,40,50,60,70,80,90,'a'])
print(s)
print(type(s))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# 7    80
# 8    90
# 9     a
# dtype: object
# <class 'pandas.Series'>

# %% [markdown]
# # 📖 Creating a Series Using a Dictionary
#
# You can easily create a Pandas Series using a standard Python dictionary. When you pass a dictionary into a Series, Pandas automatically maps the components as follows:
#
# * **Dictionary Keys** ➡️ Become the Series **Index** (row labels)
# * **Dictionary Values** ➡️ Become the Series **Data**
#
# ## 💡 Quick Example Concept:
#
# If you have a dictionary like `{'Apples': 5, 'Bananas': 10}`:
# * `"Apples"` and `"Bananas"` (the keys) become your **Index**.
# * `5` and `10` (the values) become your **Data**.

# %%
#creating series using dict
#key ---> index
#value ---> data
s1=pd.Series({'a':101,'b':'hello','c':'pandas'})
print(s1)
print(type(s1))
# Out:
# a       101
# b     hello
# c    pandas
# dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# # 🗄️ Pandas DataFrame in Detail
#
# ## What is a DataFrame?
# * **Structure:** A **two-dimensional**, labeled, tabular data structure in Python.
# * **Visualization:** Think of it as a standard data table composed of **rows and columns** (much like an Excel spreadsheet or a SQL table).
#
# ## The Core Concept
# At its structural level, a DataFrame is simply a collection of Series bound together:
# > **DataFrame = Multiple Series aligned by a common Index**

# %% [markdown]
# # creating dataframe using dictionary

# %%
d1={'a':['raju','amit','smiran'],'b':[101,102,103],'c':['red','yellow','green']}
print(d1)
# Out:
# {'a': ['raju', 'amit', 'smiran'], 'b': [101, 102, 103], 'c': ['red', 'yellow', 'green']}

# %%
df1=pd.DataFrame(d1)
print(df1)
# Out:
#         a    b       c
# 0    raju  101     red
# 1    amit  102  yellow
# 2  smiran  103   green

# %% [markdown]
# # creating df using list

# %%
data=[['rahul',21,86],
      ['priya',22,90],
      ['amit',20,78]]
df=pd.DataFrame(data,columns=['name','age','marks'])
print(df)
# Out:
#     name  age  marks
# 0  rahul   21     86
# 1  priya   22     90
# 2   amit   20     78

# %%
my_data = [
    ['amiku', 19, 98],
    ['sonal', 19, 96],
    ['mohak', 20, 88],
    ['gouri'] # this will add a NaN value at the place of age and percentage columns
]

data_f = pd.DataFrame(my_data, columns=['name', 'age', 'percentage'])
print(data_f)

print(data_f.shape) # this will print (4,3) - 4 rows , 3 columns and NaN value ignored

print(data_f.describe()) # It will work only on Numerical columns and NaN values ignored
# Out:
#     name   age  percentage
# 0  amiku  19.0        98.0
# 1  sonal  19.0        96.0
# 2  mohak  20.0        88.0
# 3  gouri   NaN         NaN
# (4, 3)
#              age  percentage
# count   3.000000    3.000000
# mean   19.333333   94.000000
# std     0.577350    5.291503
# min    19.000000   88.000000
# 25%    19.000000   92.000000
# 50%    19.000000   96.000000
# 75%    19.500000   97.000000
# max    20.000000   98.000000

# %% [markdown]
# # reading the files
#
# ## df=pd.read_excel("path") **`reading excel file`**
# ## df=pd.read_csv("path") **`reading csv file`**

# %%
# basic dataframe attributes

d1={'a':['raju','amit','smiran'],'b':[101,102,103],'c':['red','yellow','green']}
df2=pd.DataFrame(d1)
print(df2)
print(df2.shape)
# Out:
#         a    b       c
# 0    raju  101     red
# 1    amit  102  yellow
# 2  smiran  103   green
# (3, 3)

# %% [markdown]
# # shape -- number of rows and columns

# %%
print(df2.shape)
# Out:
# (3, 3)

# %% [markdown]
# # size -- total numbers of elements

# %%
print(df2.size)
# Out:
# 9

# %% [markdown]
# # columns --- display all the columns present in dataframe

# %%
print(df2.columns)
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %% [markdown]
# # dtype -- datatype of each columns

# %%
print(df2.dtypes)
# Out:
# a    object
# b     int64
# c    object
# dtype: object

# %% [markdown]
# # viewing the data

# %%
print(df2)
# Out:
#         a    b       c
# 0    raju  101     red
# 1    amit  102  yellow
# 2  smiran  103   green

# %% [markdown]
# # head() --- give me only the top most row

# %%
print(df2.head()) #default value is 5(first five)
# Out:
#         a    b       c
# 0    raju  101     red
# 1    amit  102  yellow
# 2  smiran  103   green

# %% [markdown]
# # tail() -- it will give me bottom rows(default 5)

# %%
print(df2.tail(1))
# Out:
#         a    b      c
# 2  smiran  103  green

# %% [markdown]
# # info() --- information of data ---> columns,null values count,datatypes

# %%
print(df2.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       3 non-null      str
#  1   b       3 non-null      int64
#  2   c       3 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 232.0 bytes
# None

# %%
print(data_f.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        4 non-null      str
#  1   age         3 non-null      float64
#  2   percentage  3 non-null      float64
# dtypes: float64(2), str(1)
# memory usage: 248.0 bytes
# None

# %% [markdown]
# # describe() -- statistical summary of data
# ### it will work only on numberic columns

# %%
print(df2.describe())
# Out:
#            b
# count    3.0
# mean   102.0
# std      1.0
# min    101.0
# 25%    101.5
# 50%    102.0
# 75%    102.5
# max    103.0

# %% [markdown]
# # sample --- >it will give random rows

# %%
print(df.sample(2))
# Out:
#     name  age  marks
# 2   amit   20     78
# 0  rahul   21     86
