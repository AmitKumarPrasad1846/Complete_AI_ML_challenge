# %% [markdown]
# # Create a class Student with private attributes name and marks. Provide getter and setter methods. Prevent marks from being set below 0 or above 100.

# %%
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.set_marks(marks)

    # Getter and Setter for Name
    def get_name(self):
        return self.name

    def set_name(self, name):
        self.name = name

    # Getter and Setter for Marks
    def get_marks(self):
        return self.marks

    def set_marks(self, marks):
        if 0 <= marks <= 100:
            self.marks = marks
        else:
            print("Invalid marks! It must be between 0 and 100.")

# running the class...

s = Student("Amit", 85)
print(s.get_name(), s.get_marks())

s.set_marks(105) # output : Invalid marks! It must be between 0 and 100.
# Out:
# Amit 85
# Invalid marks! It must be between 0 and 100.

# %% [markdown]
# # Print first N prime numbers efficiently.

# %%
n = int(input("How many Prime no. you want to print? = "))

prime = []
num = 2

while len(prime) < n:
    for i in range(2, num):
        if num % i == 0:
            break
    else:
        prime.append(num)
    num += 1

print(prime)
# Out:
# [2, 3, 5, 7, 11]

# %% [markdown]
# # dataset link - https://www.kaggle.com/datasets/yasserh/titanic-dataset
#
# # show first 10 rows
# # show bottom 10 rows
# # Detect Duplicates
# # detect Null values

# %%
import pandas as pd
df = pd.read_csv('Titanic-Dataset.csv')

# 1. Show first 10 rows
print("First 10 Rows")
print(df.head(10))

# 2. Show bottom 10 rows
print("\nBottom 10 Rows")
print(df.tail(10))

# 3. Detect Duplicates
print("\nTotal Duplicate Rows")
print(df.duplicated().sum())

# 4. Detect Null Values
print("\nNull Values Count per Column")
print(df.isnull().sum())
# Out:
# First 10 Rows
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...
